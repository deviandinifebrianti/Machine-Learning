# %% [markdown]
# <a href="https://colab.research.google.com/github/deviandinifebrianti/Machine-Learning/blob/main/Tugas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Modifikasi model CNN pada praktikum 2 sehingga didapatkan akurasi testing lebih dari 80%.**

# %%
import tensorflow as tf#untuk pengembangan jaringan saraf
from tensorflow.keras import datasets, layers, utils, models, callbacks# untuk membangun, melatih, dan menguji model jaringan saraf.
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt#untuk membuat visualisasi dan plot data

# %%
(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()

# Scale the data
X_train = X_train / 255.0
X_test = X_test / 255.0

# Transform target variable into one-hotencoding
y_cat_train = utils.to_categorical(y_train, 10)
y_cat_test = utils.to_categorical(y_test, 10)

INPUT_SHAPE = (32, 32, 3)
KERNEL_SIZE = (3, 3)
model = models.Sequential()

# Convolutional Layer
model.add(layers.Conv2D(filters=32, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(filters=32, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
# Pooling layer
model.add(layers.MaxPool2D(pool_size=(2, 2)))
# Dropout layers
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=64, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(filters=64, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=128, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(filters=128, kernel_size=KERNEL_SIZE, input_shape=INPUT_SHAPE, activation='relu', padding='same'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.25))

model.add(layers.Flatten())
# model.add(layers.Dropout(0.2))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(layers.Dense(10, activation='softmax'))

METRICS = [
    'accuracy',
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall')
]
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=METRICS)

early_stop = callbacks.EarlyStopping(monitor='val_loss', patience=2)

batch_size = 32
data_generator = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
train_generator = data_generator.flow(X_train, y_cat_train, batch_size)
steps_per_epoch = X_train.shape[0] // batch_size

r = model.fit(train_generator,
              epochs=50,
              steps_per_epoch=steps_per_epoch,
              validation_data=(X_test, y_cat_test),
#               callbacks=[early_stop],
#               batch_size=batch_size,
             )
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# Epoch 1/50
# 1562/1562 [==============================] - 61s 30ms/step - loss: 1.6316 - accuracy: 0.4146 - precision: 0.6249 - recall: 0.2023 - val_loss: 1.1611 - val_accuracy: 0.5845 - val_precision: 0.7419 - val_recall: 0.4392
# Epoch 2/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 1.2215 - accuracy: 0.5662 - precision: 0.7287 - recall: 0.4012 - val_loss: 1.1386 - val_accuracy: 0.6198 - val_precision: 0.7663 - val_recall: 0.4958
# Epoch 3/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 1.0411 - accuracy: 0.6365 - precision: 0.7706 - recall: 0.5055 - val_loss: 0.9480 - val_accuracy: 0.6761 - val_precision: 0.7762 - val_recall: 0.5871
# Epoch 4/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 0.9349 - accuracy: 0.6785 - precision: 0.7952 - recall: 0.5655 - val_loss: 0.7822 - val_accuracy: 0.7364 - val_precision: 0.8550 - val_recall: 0.6238
# Epoch 5/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.8626 - accuracy: 0.7067 - precision: 0.8092 - recall: 0.6039 - val_loss: 0.7484 - val_accuracy: 0.7412 - val_precision: 0.8292 - val_recall: 0.6686
# Epoch 6/50
# 1562/1562 [==============================] - 47s 30ms/step - loss: 0.8081 - accuracy: 0.7245 - precision: 0.8233 - recall: 0.6321 - val_loss: 0.6864 - val_accuracy: 0.7686 - val_precision: 0.8396 - val_recall: 0.7006
# Epoch 7/50
# 1562/1562 [==============================] - 41s 27ms/step - loss: 0.7653 - accuracy: 0.7404 - precision: 0.8319 - recall: 0.6563 - val_loss: 0.7001 - val_accuracy: 0.7612 - val_precision: 0.8373 - val_recall: 0.6937
# Epoch 8/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.7237 - accuracy: 0.7558 - precision: 0.8373 - recall: 0.6768 - val_loss: 0.6498 - val_accuracy: 0.7844 - val_precision: 0.8534 - val_recall: 0.7180
# Epoch 9/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 0.6892 - accuracy: 0.7660 - precision: 0.8466 - recall: 0.6943 - val_loss: 0.6222 - val_accuracy: 0.7955 - val_precision: 0.8576 - val_recall: 0.7400
# Epoch 10/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.6650 - accuracy: 0.7748 - precision: 0.8510 - recall: 0.7060 - val_loss: 0.6032 - val_accuracy: 0.8010 - val_precision: 0.8527 - val_recall: 0.7519
# Epoch 11/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.6348 - accuracy: 0.7846 - precision: 0.8542 - recall: 0.7202 - val_loss: 0.5850 - val_accuracy: 0.8077 - val_precision: 0.8572 - val_recall: 0.7634
# Epoch 12/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 0.6185 - accuracy: 0.7926 - precision: 0.8610 - recall: 0.7303 - val_loss: 0.6274 - val_accuracy: 0.8029 - val_precision: 0.8567 - val_recall: 0.7500
# Epoch 13/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.5994 - accuracy: 0.7982 - precision: 0.8649 - recall: 0.7371 - val_loss: 0.5926 - val_accuracy: 0.7997 - val_precision: 0.8510 - val_recall: 0.7544
# Epoch 14/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.5793 - accuracy: 0.8038 - precision: 0.8662 - recall: 0.7463 - val_loss: 0.5132 - val_accuracy: 0.8297 - val_precision: 0.8787 - val_recall: 0.7816
# Epoch 15/50
# Epoch 39/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.4024 - accuracy: 0.8622 - precision: 0.9018 - recall: 0.8287 - val_loss: 0.4401 - val_accuracy: 0.8548 - val_precision: 0.8860 - val_recall: 0.8305
# Epoch 40/50
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.3967 - accuracy: 0.8656 - precision: 0.9023 - recall: 0.8314 - val_loss: 0.4418 - val_accuracy: 0.8583 - val_precision: 0.8885 - val_recall: 0.8347
# Epoch 41/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.3933 - accuracy: 0.8645 - precision: 0.9002 - recall: 0.8324 - val_loss: 0.4174 - val_accuracy: 0.8666 - val_precision: 0.8973 - val_recall: 0.8397
# Epoch 42/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.3872 - accuracy: 0.8673 - precision: 0.9045 - recall: 0.8359 - val_loss: 0.3892 - val_accuracy: 0.8737 - val_precision: 0.9027 - val_recall: 0.8517
# Epoch 43/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 0.3860 - accuracy: 0.8676 - precision: 0.9033 - recall: 0.8357 - val_loss: 0.4622 - val_accuracy: 0.8521 - val_precision: 0.8826 - val_recall: 0.8281
# Epoch 44/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.3851 - accuracy: 0.8689 - precision: 0.9049 - recall: 0.8366 - val_loss: 0.4195 - val_accuracy: 0.8622 - val_precision: 0.8889 - val_recall: 0.8418
# Epoch 45/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.3778 - accuracy: 0.8703 - precision: 0.9035 - recall: 0.8399 - val_loss: 0.3889 - val_accuracy: 0.8739 - val_precision: 0.9036 - val_recall: 0.8496
# Epoch 46/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 0.3736 - accuracy: 0.8729 - precision: 0.9075 - recall: 0.8424 - val_loss: 0.4553 - val_accuracy: 0.8558 - val_precision: 0.8850 - val_recall: 0.8322
# Epoch 47/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.3753 - accuracy: 0.8727 - precision: 0.9067 - recall: 0.8420 - val_loss: 0.4239 - val_accuracy: 0.8619 - val_precision: 0.8932 - val_recall: 0.8380
# Epoch 48/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.3696 - accuracy: 0.8749 - precision: 0.9089 - recall: 0.8450 - val_loss: 0.4128 - val_accuracy: 0.8704 - val_precision: 0.8968 - val_recall: 0.8506
# Epoch 49/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.3689 - accuracy: 0.8738 - precision: 0.9073 - recall: 0.8445 - val_loss: 0.4176 - val_accuracy: 0.8717 - val_precision: 0.8940 - val_recall: 0.8547
# Epoch 50/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.3669 - accuracy: 0.8744 - precision: 0.9076 - recall: 0.8440 - val_loss: 0.3895 - val_accuracy: 0.8759 - val_precision: 0.9022 - val_recall: 0.8538

# %%
plt.figure(figsize=(12, 16))

plt.subplot(4, 2, 1)
plt.plot(r.history['loss'], label='Loss')
plt.plot(r.history['val_loss'], label='val_Loss')
plt.title('Loss Function Evolution')
plt.legend()

plt.subplot(4, 2, 2)
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.title('Accuracy Function Evolution')
plt.legend()

plt.subplot(4, 2, 3)
plt.plot(r.history['precision'], label='precision')
plt.plot(r.history['val_precision'], label='val_precision')
plt.title('Precision Function Evolution')
plt.legend()

plt.subplot(4, 2, 4)
plt.plot(r.history['recall'], label='recall')
plt.plot(r.history['val_recall'], label='val_recall')
plt.title('Recall Function Evolution')
plt.legend()

evaluation = model.evaluate(X_test, y_cat_test)
print(f'Test Accuracy : {evaluation[1] * 100:.2f}%')
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3895 - accuracy: 0.8759 - precision: 0.9022 - recall: 0.8538
# Test Accuracy : 87.59%

# %% [markdown]
# *Tugas 2*
#
# **Buatlah model CNN untuk klasifikasi dataset MNIST.**

# %%
# Load and preprocess the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# Reshape the data to fit the model
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1)
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1)

# Define the CNN model
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print("Test accuracy:", test_acc)

# Plot training accuracy and loss
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 12s 5ms/step - loss: 0.1386 - accuracy: 0.9565 - val_loss: 0.0477 - val_accuracy: 0.9847
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0443 - accuracy: 0.9865 - val_loss: 0.0360 - val_accuracy: 0.9891
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0325 - accuracy: 0.9895 - val_loss: 0.0292 - val_accuracy: 0.9908
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0250 - accuracy: 0.9924 - val_loss: 0.0274 - val_accuracy: 0.9922
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0199 - accuracy: 0.9938 - val_loss: 0.0290 - val_accuracy: 0.9915
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0378 - val_accuracy: 0.9888
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.0265 - val_accuracy: 0.9927
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.0270 - val_accuracy: 0.9924
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.0296 - val_accuracy: 0.9927
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0409 - val_accuracy: 0.9896
# 313/313 - 1s - loss: 0.0409 - accuracy: 0.9896 - 681ms/epoch - 2ms/step
# Test accuracy: 0.9896000027656555
